# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#PACU-centers-in-the-US" data-toc-modified-id="PACU-centers-in-the-US-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>PACU centers in the US</a></span></li><li><span><a href="#Reading-secondary-file-(based-on-NS's-notebook-)" data-toc-modified-id="Reading-secondary-file-(based-on-NS's-notebook-)-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Reading secondary file (based on NS's notebook )</a></span><ul class="toc-item"><li><span><a href="#CMS-file" data-toc-modified-id="CMS-file-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>CMS file</a></span><ul class="toc-item"><li><span><a href="#Confirm-CMS-data-import" data-toc-modified-id="Confirm-CMS-data-import-2.1.1"><span class="toc-item-num">2.1.1&nbsp;&nbsp;</span>Confirm CMS data import</a></span></li></ul></li><li><span><a href="#Final-merge-of-NS-and-CMS-data" data-toc-modified-id="Final-merge-of-NS-and-CMS-data-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Final merge of NS and CMS data</a></span><ul class="toc-item"><li><span><a href="#Fixing-repeated-numbers----FIXED" data-toc-modified-id="Fixing-repeated-numbers----FIXED-2.2.1"><span class="toc-item-num">2.2.1&nbsp;&nbsp;</span>Fixing repeated numbers -- FIXED</a></span></li><li><span><a href="#Fixing-centers-not-matched-with-CMS----FIXED" data-toc-modified-id="Fixing-centers-not-matched-with-CMS----FIXED-2.2.2"><span class="toc-item-num">2.2.2&nbsp;&nbsp;</span>Fixing centers not matched with CMS -- FIXED</a></span><ul class="toc-item"><li><span><a href="#Wakemed-Raleigh" data-toc-modified-id="Wakemed-Raleigh-2.2.2.1"><span class="toc-item-num">2.2.2.1&nbsp;&nbsp;</span>Wakemed Raleigh</a></span></li><li><span><a href="#Mission-Children's-Hospital---Asheville-NC" data-toc-modified-id="Mission-Children's-Hospital---Asheville-NC-2.2.2.2"><span class="toc-item-num">2.2.2.2&nbsp;&nbsp;</span>Mission Children's Hospital - Asheville NC</a></span></li><li><span><a href="#Fixing-duplicates" data-toc-modified-id="Fixing-duplicates-2.2.2.3"><span class="toc-item-num">2.2.2.3&nbsp;&nbsp;</span>Fixing duplicates</a></span></li><li><span><a href="#Confirm-changes-work" data-toc-modified-id="Confirm-changes-work-2.2.2.4"><span class="toc-item-num">2.2.2.4&nbsp;&nbsp;</span>Confirm changes work</a></span></li></ul></li><li><span><a href="#Selecting-only-centers-with-some-level-of-pediatrics---FIXED" data-toc-modified-id="Selecting-only-centers-with-some-level-of-pediatrics---FIXED-2.2.3"><span class="toc-item-num">2.2.3&nbsp;&nbsp;</span>Selecting only centers with some level of pediatrics - FIXED</a></span></li><li><span><a href="#Matches-list-without-Shrine-from-NS?" data-toc-modified-id="Matches-list-without-Shrine-from-NS?-2.2.4"><span class="toc-item-num">2.2.4&nbsp;&nbsp;</span>Matches list without Shrine from NS?</a></span></li><li><span><a href="#A-few-tests-to-make-sure-facilities-are-matched-appropriately" data-toc-modified-id="A-few-tests-to-make-sure-facilities-are-matched-appropriately-2.2.5"><span class="toc-item-num">2.2.5&nbsp;&nbsp;</span>A few tests to make sure facilities are matched appropriately</a></span></li></ul></li><li><span><a href="#Saving-merged-dataset" data-toc-modified-id="Saving-merged-dataset-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>Saving merged dataset</a></span></li></ul></li><li><span><a href="#Creating-final-dataset" data-toc-modified-id="Creating-final-dataset-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Creating final dataset</a></span><ul class="toc-item"><li><span><a href="#Fixing-STATUS-using-the-new-definitions" data-toc-modified-id="Fixing-STATUS-using-the-new-definitions-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Fixing STATUS using the new definitions</a></span></li></ul></li><li><span><a href="#Geocoding-centers" data-toc-modified-id="Geocoding-centers-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Geocoding centers</a></span><ul class="toc-item"><li><span><a href="#Checking-and-cleaning-centers-without-address" data-toc-modified-id="Checking-and-cleaning-centers-without-address-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Checking and cleaning centers without address</a></span><ul class="toc-item"><li><span><a href="#Apparently,-all-centers-have-full-address,-but-just-in-case" data-toc-modified-id="Apparently,-all-centers-have-full-address,-but-just-in-case-4.1.1"><span class="toc-item-num">4.1.1&nbsp;&nbsp;</span>Apparently, all centers have full address, but just in case</a></span></li></ul></li><li><span><a href="#Geocoding" data-toc-modified-id="Geocoding-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>Geocoding</a></span></li><li><span><a href="#Merging-geocoding-results-back-to-main-dataframe" data-toc-modified-id="Merging-geocoding-results-back-to-main-dataframe-4.3"><span class="toc-item-num">4.3&nbsp;&nbsp;</span>Merging geocoding results back to main dataframe</a></span></li><li><span><a href="#Centers-&amp;-adresses-not-geocoded----FIXED" data-toc-modified-id="Centers-&amp;-adresses-not-geocoded----FIXED-4.4"><span class="toc-item-num">4.4&nbsp;&nbsp;</span>Centers &amp; adresses not geocoded -- FIXED</a></span><ul class="toc-item"><li><span><a href="#Any-other-centers-without-latitude-or-longitude?" data-toc-modified-id="Any-other-centers-without-latitude-or-longitude?-4.4.1"><span class="toc-item-num">4.4.1&nbsp;&nbsp;</span>Any other centers without latitude or longitude?</a></span></li></ul></li><li><span><a href="#Write-geocoded-dataset-to-file" data-toc-modified-id="Write-geocoded-dataset-to-file-4.5"><span class="toc-item-num">4.5&nbsp;&nbsp;</span>Write geocoded dataset to file</a></span></li></ul></li><li><span><a href="#FINAL-dataset:-to-be-published" data-toc-modified-id="FINAL-dataset:-to-be-published-5"><span class="toc-item-num">5&nbsp;&nbsp;</span><font color="red">FINAL dataset</font>: to be published</a></span></li></ul></div>

# %% [markdown]
# # PACU centers in the US
#
# __N Straka, UL França, ML McManus__

# %%
# %matplotlib inline
user = 'UF'

import datetime as dt
import pandas as pd
import sys
import csv
import glob
import ipywidgets #as widgets
import itertools
import numpy as np
import matplotlib.pyplot as plt
import datetime
import seaborn as sns
import socket


import requests
import logging
import time

from matplotlib import *
from matplotlib.dates import YearLocator, MonthLocator, DateFormatter
from matplotlib.dates import *
#style.use('ggplot')
from numpy.random import randn
#from scipy import statss
from pandas import  DataFrame, Series
import statsmodels.api as sm

from ipywidgets import interact, interactive, fixed, interact_manual
import ipywidgets as widgets

import plotly.express as px
import plotly.graph_objects as go
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot
from plotly.subplots import make_subplots

sns.set()

import warnings
warnings.filterwarnings('ignore')

## display entire text columns
pd.set_option('display.max_colwidth', -1)
pd.set_option("display.max_columns", None)

today = dt.datetime.today().strftime("%y%m%d")
print(today)


if user == 'UF':

    # %run py_addresses.py

elif user =='MM':
    ## Here I define 
    #'addressdata', which is the folder where the data is located
    # 'data_tools', which is where the data_tools are located
    # 'address' is not used anywhere and mostly deprecated
    print(user)
    
elif user =='NS':
    ## Here I define 
    #'addressdata', which is the folder where the data is located
    # 'data_tools', which is where the data_tools are located
    # 'address' is not used anywhere and mostly deprecated
    print(user)
    
else:
    print("Define the paths for `address`, `addressdata`, and `data_tools`")
    
    
from IPython.core.display import HTML
HTML("<style>.container { width:80% !important; }</style>")
# Out:
# 230330
# urbanos-air
# Running on the laptop
# /Users/ufranca/Documents/Data/ /Users/ufranca/Documents/Data/new_datasets/
# External == True
# <style>.container { width:80% !important; }</style>

# %% [markdown]
# # Reading secondary file (based on NS's notebook )
#
# Based on the notebook `09292022_PAC_AHA_report.ipynb`
#
# <font color="red">Nadine, I don't think I have the final version of your dataset you used to create this merged file.I do have the 50 states separately, but the files I have don't have the flags for trach, etc.</font>

# %% [markdown]
# ## CMS file
#
# The cells below are not necessarily used because we'll be loading the merged CMS+NS dataset, but will be using to check any number not available

# %%
#path= 'dataset/provider_of_services_file_hospital_non_hospital_facilities_2021_06_30.csv'
path= 'dataset/data_Dec2022/CMS1220.csv'

CMS= pd.read_csv (path,#path + 'CMS1220.csv',
                  encoding = "ISO-8859-1",
                  dtype=object,
                  low_memory=False)


CMS['PRVDR_NUM'] = CMS['PRVDR_NUM'].astype(str).str.zfill(6)
CMS.sample(3)
# Out:
#        PRVDR_CTGRY_SBTYP_CD PRVDR_CTGRY_CD CHOW_CNT CHOW_DT    CITY_NAME  \
# 107515  01                   15             1        NaN     BALA CYNWYD
# 829     01                   12             0        NaN     SAMSON
# 40381   03                   03             4        NaN     MONTICELLO
#
#        ACPTBL_POC_SW CMPLNC_STUS_CD SSA_CNTY_CD CROSS_REF_PROVIDER_NUMBER  \
# 107515  Y             A              560         NaN
# 829     N             A              300         NaN
# 40381   Y             A              900         NaN
#
#        CRTFCTN_DT ELGBLTY_SW                                 FAC_NAME  \
# 107515  20180810   Y          DELAWARE VALLEY LASER SURGERY INSTITUTE
# 829     19950426   Y          SAMSON FAMILY HEALTH CENTER
# 40381   20191025   Y          MONTICELLO HEALTHCARE
#
#        INTRMDRY_CARR_CD MDCD_VNDR_NUM ORGNL_PRTCPTN_DT CHOW_PRIOR_DT  \
# 107515  12502            100739552     19891024         19820907
# ...

# %% [markdown]
# ### Confirm CMS data import

# %%
## Just to avoid confusion, changing the field FAC_NAME to FAC_NAME_CMS, so we have it differently from FAC_NAME in Nadine's dataset
CMS = CMS.rename(columns={'FAC_NAME':'FAC_NAME_CMS',
                          'ST_ADR': 'ST_ADR_CMS'})

# %%
CMS.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 152080 entries, 0 to 152079
# Columns: 473 entries, PRVDR_CTGRY_SBTYP_CD to DLYS_STN_CNT
# dtypes: object(473)
# memory usage: 548.8+ MB

# %% [markdown]
# ## Final merge of NS and CMS data
#
# Loading the merged file sent by Nadine

# %%
## Files from Dec 2022

#path1= 'dataset/data_Dec2022/pac_facilities_and_cms_merge_230327.csv'
path1= 'dataset/data_Dec2022/pac_facilities_and_cms_merge_no_shrine_230327.csv'
#path1= 'dataset/data_Dec2022/pac_facilities_and_cms_merge_old_230328.csv'
df4= pd.read_csv (path1,
                  encoding = "ISO-8859-1",
                  dtype=object,
                  low_memory=False)

## Just fixing the names to reflect their origin
# df4 = df4.rename(columns={'FAC_NAME_x':'FAC_NAME_NS',
#                           'ST_ADR_x': 'ST_ADR_NS',
#                           'FAC_NAME_y':'FAC_NAME_CMS',
#                           'ST_ADR_y': 'ST_ADR_CMS'})
df4 = df4.rename(columns={'FAC_NAME':'FAC_NAME_NS',
                          'ST_ADR': 'ST_ADR_NS'})


display(df4.sample(3))
#df4.shape
# Out:
#      STATE                                         FAC_NAME_NS  \
# 1330  WV    ACUITY SPECIALTY HOSPITAL OHIO VALLEY
# 275   NJ    CARE ONE AT RARITAN BAY MEDICAL CENTER
# 1130  CO    NORTHERN COLORADO LONG TERM ACUTE HOSP - LONG TERM
#
#                        ST_ADR_NS       PHONE  \
# 1330  601 COLLIERS WAY 9TH FLOOR  7402837497
# 275   530 NEW BRUNSWICK AVENUE    7323246090
# 1130  4401A UNION ST              9706193663
#
#                                                                                                                                                                                                                                                                                                                                                                               INFO_PHONE  \
# ...

# %%
df4.shape
# Out:
# (1340, 499)

# %%
df4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1340 entries, 0 to 1339
# Columns: 499 entries, STATE to DLYS_STN_CNT
# dtypes: object(499)
# memory usage: 5.1+ MB

# %% [markdown]
# ### Fixing repeated numbers -- FIXED
#
# <s><font color ='red'> There are 2 repeated CMS numbers: '452057', '103301'</font> (see above). For now, will <font color ='red'> __remove__</font> one of each, but remember to ask MM and NS about it.</s>
#
# NS fixed them

# %%
df4['PRVDR_NUM'].value_counts()
# Out:
# 70029     1
# 013029    1
# 360086    1
# 367518    1
# 363303    1
#          ..
# 16A001    1
# 163027    1
# 230046    1
# 230300    1
# 513030    1
# Name: PRVDR_NUM, Length: 443, dtype: int64

# %%
# #list of centers with repeated provider numbers

# list_repeated = ['452057', '103301']

# for repeated in list_repeated:
#     display(df4[df4['PRVDR_NUM'] == repeated])
#     print("="*80)

# %%
## How many centers with and without provider numbers?

df4['PRVDR_NUM'] = df4['PRVDR_NUM'].astype(str)

print("Providers == nan: %s" % len(df4[df4['PRVDR_NUM']=='nan']))
print("Providers != nan: %s" % len(df4[df4['PRVDR_NUM']!='nan']))
print("Providers != nan (unique): %s" % len(df4[df4['PRVDR_NUM']!='nan']['PRVDR_NUM'].unique()))

## Adding a flag on centers with provider numbers to filter later
df4['provider_nan'] = np.where(df4['PRVDR_NUM']=='nan', 'nan', 'no_nan')

## Z filling, just in case
df4['PRVDR_NUM'] = df4['PRVDR_NUM'].astype(str).str.zfill(6)

df4['provider_nan'].value_counts()
# Out:
# Providers == nan: 897
# Providers != nan: 443
# Providers != nan (unique): 443
# nan       897
# no_nan    443
# Name: provider_nan, dtype: int64

# %%
df4 = df4[(df4['provider_nan']=='no_nan')]
print(len(df4))

# removing duplicate NICKLAUS CHILDREN'S HOSPITAL, ['PRVDR_NUM'] == '103301'
df4 = df4[(df4['ST_ADR_NS'] != '5959 NW 7TH ST')]
print(len(df4))

# # removing duplicate NEXUS CHILDRENS HOSPITAL, ['PRVDR_NUM'] == '452057'
# df4['INPT_BEDS'] = np.where(((df4['ST_ADR_NS'] != '9182 SIX PINES DRIVE') & (df4['PRVDR_NUM'] == '452057')),
#                             36, 
#                             df4['INPT_BEDS'])

# df4 = df4[(df4['ST_ADR_NS'] != '123 VISION PARK BLVD')]
print(len(df4))
# Out:
# 443
# 443
# 443

# %% [markdown]
# ### Fixing centers not matched with CMS -- FIXED
#
# Only three centers without CSM numbers, obtained from the states

# %%
#put df3['PRVDR_NUM'] on a list to compare to CMS 

list_from_data = list(df4[df4['provider_nan'] == 'no_nan']['PRVDR_NUM'].unique())
print(len(list_from_data))
# Out:
# 443

# %%
#put CMS['PRVDR_NUM']  on a list to compare to df3 above

list_from_CMS = list(CMS['PRVDR_NUM'].unique())
print(len(list_from_CMS))
# Out:
# 152080

# %%
## Check if any PRVDR_NUM on NS's data is not in the CMS list

set(list_from_data).difference(set(list_from_CMS))
# Out:
# {'MISS01', 'MISS02', 'MISS03'}

# %%
df4[df4['PRVDR_NUM'].isin(['027610', '028801'])]
# Out:
# Empty DataFrame
# ...

# %% [markdown]
# #### Wakemed Raleigh

# %%
##Look for center by name and location
#CMS[CMS['FAC_NAME_CMS'].str.contains('WAKEMED')]

# %% [markdown]
# #### Mission Children's Hospital - Asheville NC

# %%
#CMS[CMS['FAC_NAME_CMS'].str.contains("MISSION HOSPITAL")]

# %% [markdown]
# #### Fixing duplicates
#
# Since we already have the merged dataset, we need to re-merge these two entries to ensure they match the CMS numbers above.

# %%
list_cols_ns = list(df4.columns)[:27]

# %%
# ## df4 only with NS original columns
# df_fix_duplicates = df4[df4['PRVDR_NUM'].isin(['340002', '340069'])][list_cols_ns]

# ## merge with CMS
# df_fix_duplicates = df_fix_duplicates.merge(CMS, how='inner', on='PRVDR_NUM')
# df_fix_duplicates

# ## remove "wrong" rows
# print(len(df4))
# df4 = df4[~df4['PRVDR_NUM'].isin(['340002', '340069','027610', '028801'])]
# print(len(df4))

# # concatenate the fixed ones back
# df4 = pd.concat([df4, df_fix_duplicates])
# print(len(df4))

# %% [markdown]
# #### Confirm changes work

# %%
list_from_data = list(df4[df4['provider_nan'] == 'no_nan']['PRVDR_NUM'].unique())
print(len(list_from_data))

## Check if any CMS on df3 is not in the list: if empty set, change of numebrs worked
list_not_cms = list(set(list_from_data).difference(set(list_from_CMS)))

set(list_from_data).difference(set(list_from_CMS))
# Out:
# 443
# {'MISS01', 'MISS02', 'MISS03'}

# %% [markdown]
# ### Selecting only centers with some level of pediatrics - FIXED
#
# <s>__Should we remove all Shrine centers?__ Or just one/some? </s>
#
# NS removed them, so these next few cells should not have any effect

# %%
df4['STATUS'] = df4['STATUS'].astype(str)
df4['STATUS'].value_counts()
df4 = df4[df4['STATUS'].isin(['1.0', '2.0', '3.0'])]
print("Total = %s" % df4['STATUS'].value_counts().sum())
df4['STATUS'].value_counts()
# Out:
# Total = 241
# 1.0    102
# 2.0    73
# 3.0    66
# Name: STATUS, dtype: int64

# %%
### Removing Shrine
print('Len before removing Shrine: %s' % len(df4))
df4 = df4[~df4['FAC_NAME_NS'].str.contains('SHRINE')]
print('Len after removing Shrine: %s' % len(df4))
# Out:
# Len before removing Shrine: 241
# Len after removing Shrine: 241

# %% [markdown]
# ### Matches list without Shrine from NS?

# %%
path1= 'csv_data_230327/pac_facilities_and_cms_merge_noshrine_peds_only.csv'

df5= pd.read_csv (path1,
                  encoding = "ISO-8859-1",
                  dtype=object,
                  low_memory=False)

# Just fixing the names to reflect their origin
# df4 = df4.rename(columns={'FAC_NAME_x':'FAC_NAME_NS',
#                           'ST_ADR_x': 'ST_ADR_NS',
#                           'FAC_NAME_y':'FAC_NAME_CMS',
#                           'ST_ADR_y': 'ST_ADR_CMS'})
df5 = df5.rename(columns={'FAC_NAME':'FAC_NAME_NS',
                          'ST_ADR': 'ST_ADR_NS'})


#display(df4.sample(3))

df5.shape
# Out:
# (241, 499)

# %%
## Check if any PRVDR_NUM on NS's data is not in the modified list

list_from_this_nb = list(df4['PRVDR_NUM'].unique())
list_from_ns = list(df5['PRVDR_NUM'].unique())
list_diff = list(set(list_from_ns).difference(set(list_from_this_nb)))
print(list_diff)
# Out:
# []

# %%
## rechecking with original dataset - loading it again
#path1= 'dataset/data_Dec2022/pac_facilities_and_cms_merge_230327.csv'
path1= 'dataset/data_Dec2022/pac_facilities_and_cms_merge_no_shrine_230327.csv'


df6= pd.read_csv (path1,
                  encoding = "ISO-8859-1",
                  dtype=object,
                  low_memory=False)

# Just fixing the names to reflect their origin
# df4 = df4.rename(columns={'FAC_NAME_x':'FAC_NAME_NS',
#                           'ST_ADR_x': 'ST_ADR_NS',
#                           'FAC_NAME_y':'FAC_NAME_CMS',
#                           'ST_ADR_y': 'ST_ADR_CMS'})
df6 = df6.rename(columns={'FAC_NAME':'FAC_NAME_NS',
                          'ST_ADR': 'ST_ADR_NS'})

df6=df6[df6['PRVDR_NUM'].isin(list_diff)]
df6
# Out:
# Empty DataFrame
# ...

# %% [markdown]
# ### A few tests to make sure facilities are matched appropriately

# %%
#look at identified pediatric facilities 
df_test= df4[df4.STATUS == '1.0']
print("Number of facilities: %s" % len(df_test))
df_test[['PRVDR_NUM', 'PRVDR_NUM_CHECK', 'FAC_NAME_CMS', 'FAC_NAME_NS']]
# Out:
# Number of facilities: 102
#      PRVDR_NUM PRVDR_NUM_CHECK  \
# 73    393304    393304
# 74    399812    399812
# 85    393035    393035
# 104   393302    393302
# 128   433300    433300
# ...      ...       ...
# 1273  453025    453025
# 1309  095040    095040
# 1310  095037    095037
# 1321  222035    222035
# 1322  223300    223300
#
#                                         FAC_NAME_CMS  \
# 73    CHILDREN'S HOME OF PITTSBURGH
# 74    CHILDREN'S HOSPITAL OF PHILADELPHIA TRANSPLANT
# 85    GOOD SHEPHERD REHABILITATION HOSPITAL, THE
# 104   UPMC CHILDREN'S HOSPITAL OF PITTSBURGH
# 128   LIFESCAPE
# ...         ...
# 1273  TIRR MEMORIAL HERMANN
# 1309  THE HSC PEDIATRIC SKILLED NURSING FACILITY
# 1310  NATIONAL REHABILITATION HOSP TRANS CAR
# 1321  SPAULDING REHABILITATION HOSPITAL
# 1322  FRANCISCAN CHILDREN'S HOSPITAL & REHAB CENTER
#
#                                           FAC_NAME_NS
# 73    CHILDREN'S HOME OF PITTSBURGH
# 74    CHILDREN'S HOSPITAL OF PHILADELPHIA, THE
# ...

# %%
#look at facilities that accept adolescents
df_test= df4[df4.STATUS == '2.0']
print("Number of facilities: %s" % len(df_test))
df_test[['PRVDR_NUM', 'PRVDR_NUM_CHECK', 'FAC_NAME_CMS', 'FAC_NAME_NS']]
# Out:
# Number of facilities: 73
#      PRVDR_NUM PRVDR_NUM_CHECK  \
# 31    073025    073025
# 71    393036    393036
# 82    393037    393037
# 91    393038    393038
# 93    393053    393053
# ...      ...       ...
# 1215  453053    453053
# 1248  459827    459827
# 1313  223026    223026
# 1333  513028    513028
# 1334  513030    513030
#
#                                             FAC_NAME_CMS  \
# 31    MOUNT SINAI REHABILITATION HOSPITAL INC
# 71    JOHN HEINZ INSTITUTE OF REHABILITATION MEDICINE
# 82    ENCOMPASS HEALTH REHABILITATION HOSPITAL OF YORK,
# 91    MAGEE REHABILITATION HOSPITAL
# 93    PENN STATE HEALTH REHABILITATION HOSPITAL
# ...                                         ...
# 1215  HEALTHSOUTH  REHABILITATION HOSPITAL OF TEXARKANA
# 1248  DOCTORS HOSPITAL AT RENAISSANCE
# 1313  ENCOMPASS HEALTH REHABILITATION HOSP OF NEW ENGLAN
# 1333  ENCOMPASS HEALTH REHAB HOSPITAL OF HUNTINGTON
# 1334  ENCOMPASS HEALTH REHAB HOSPITAL OF MORGANTOWN
#
# ...

# %%
#look at facilities that accept adolescents on a case by case basis
df_test= df4[df4.STATUS == '3.0']
print("Number of facilities: %s" % len(df_test))
df_test[['PRVDR_NUM', 'PRVDR_NUM_CHECK', 'FAC_NAME_CMS', 'FAC_NAME_NS']]
# Out:
# Number of facilities: 66
#      PRVDR_NUM PRVDR_NUM_CHECK  \
# 70    393030    393030
# 76    393046    393046
# 77    393027    393027
# 80    393026    393026
# 140   140091    140091
# ...      ...       ...
# 1255  673068    673068
# 1259  452038    452038
# 1267  673057    673057
# 1272  453091    453091
# 1282  452041    452041
#
#                                             FAC_NAME_CMS  \
# 70    ALLIED SERVICES INSTITUTE OF REHABILITATION
# 76    HEALTHSOUTH REHABILITATION HOSPITAL OF ERIE
# 77    HEALTHSOUTH HARMARVILLE REHABILITATION HOSPITAL
# 80    ENCOMPASS HEALTH REHABILITATION HOSPITAL OF READIN
# 140   THE CARLE FOUNDATION HOSPITAL
# ...                             ...
# 1255  SUGARLAND REHAB HOSPITAL
# 1259  TEXAS NEURO REHABILITATION CENTER
# 1267  WARM SPRINGS REHABILITATION HOSPITAL OF KYLE
# 1272  WESLACO REGIONAL REHABILITATION HOSPITAL LLC
# 1282  CARRUS SPECIALTY HOSPITAL
#
#                                                        FAC_NAME_NS
# ...

# %% [markdown]
# ## Saving merged dataset
#
# Not saving until the very end, so commented out

# %%
## Just copying the dataframe to a more appropriate name
df_address =  df4

## Write to file - not saving until the very end
#print(len(df_address))
#df_address.to_csv('csv_data/pac_facilities_and_cms_merge_'+today+'.csv', index=False)

# %% [markdown]
# # Creating final dataset
#
# Based on the first part of `rehab_centers_mapping_part3-v2.ipynb`

# %%
# ## Renaming the dataframe to use the code from notebook 3
# df_rehab = df_address

# df_rehab.shape

# %% [markdown]
# ## Fixing STATUS using the new definitions

# %%
df_address['STATUS'].value_counts()
# Out:
# 1.0    102
# 2.0    73
# 3.0    66
# Name: STATUS, dtype: int64

# %%
## 
df_address['STATUS_desc'] = 'PAC facility accepting adolescent patients'

df_address['STATUS_desc'] = np.where(df_address['STATUS'] == '3.0', 
                                   'PAC facility accepting pediatric patients',
                                  df_address['STATUS_desc'] )

df_address['STATUS_desc'] = np.where((df_address['STATUS'] == '1.0') & (df_address['FREE'] == '0'), 
                                   'PAC facility with embedded pediatric unit',
                                  df_address['STATUS_desc'] )

df_address['STATUS_desc'] = np.where((df_address['STATUS'] == '1.0') & (df_address['FREE'] == '1'), 
                                   'Free-standing pediatric PAC facility',
                                  df_address['STATUS_desc'] )

# %% [markdown]
# # Geocoding centers
#
# Based on the notebook `rehab_centers_geocoding_part2.ipynb`.
#
# <font color="red">Notice this is geocoding only the 447 centers selected above. If we want to geocode all the ~1350 centers, one would need to change the merge in the beginning of Sect 2.3 to and `outer` merge: </font>
#
# _df4= pd.merge(df3, CMS, how='outer', on='PRVDR_NUM')_

# %%
df_address[df_address['CITY_NAME'].isna()][['FAC_NAME_NS', 'FAC_NAME_CMS']]
# Out:
#                                                            FAC_NAME_NS  \
# 1039  ENCOMPASS HLTH. REHAB. HSPTL. OF CIN. AT NORWOOD
# 1044  ENCOMPASS HEALTH REHABILITATION HOSPITAL OF TOLEDO
# 1251  SHANNON REHABILITATION HOSPITAL AN AFFILIATE OF ENCOMPASS HEALTH
#
#      FAC_NAME_CMS
# 1039  NaN
# 1044  NaN
# 1251  NaN

# %%
## Writing full address for geocoding

df_address['FullAddress'] = df_address['PRVDR_NUM']+' - '+df_address['ST_ADR_CMS']+', '+df_address['CITY_NAME']+', '+df_address['STATE_CD']+', '+df_address['ZIP_CD']+', USA'
df_address['FullAddress'].sample(10)
# Out:
# 579     443035 - 1000 PHYSICIANS WAY, FRANKLIN, TN, 37067, USA
# 73      393304 - 5324 PENN AVENUE, PITTSBURGH, PA, 15224, USA
# 656     113300 - 1405 CLIFTON ROAD, NE, ATLANTA, GA, 30322, USA
# 1093    285127 - 1540 NORTH 72ND STREET, OMAHA, NE, 68114, USA
# 1131    062011 - 3425 S CLARKSON ST, ENGLEWOOD, CO, 80113, USA
# 1039    NaN
# 721     170203 - 1619 K 66, GALENA, KS, 66739, USA
# 847     022001 - 4800 CORDOVA STREET, ANCHORAGE, AK, 99503, USA
# 890     253025 - 1350 E WOODROW WILSON DR, JACKSON, MS, 39216, USA
# 1322    223300 - 30 WARREN STREET, BRIGHTON, MA, 02135, USA
# Name: FullAddress, dtype: object

# %%
#### Checking adresses of the centers not present in the CMS data
df4[df4['PRVDR_NUM'].isin(list_not_cms )]#['ST_ADR_NS']
# Out:
#      STATE                                                       FAC_NAME_NS  \
# 1039  OH    ENCOMPASS HLTH. REHAB. HSPTL. OF CIN. AT NORWOOD
# 1044  OH    ENCOMPASS HEALTH REHABILITATION HOSPITAL OF TOLEDO
# 1251  TX    SHANNON REHABILITATION HOSPITAL AN AFFILIATE OF ENCOMPASS HEALTH
#
#                  ST_ADR_NS       PHONE  \
# 1039  4953 SECTION AVENUE   5137129200
# 1044  4647 MONROE STREET    5672903521
# 1251  6046 APPALOOSA TRAIL  3252844000
#
#                                                                                                                                                                                                                                                                                                                                                                   INFO_PHONE  \
# ...

# %%
# Adding full adresses

df4['FullAddress'] = np.where(df4['PRVDR_NUM'] == 'MISS01', 
                              df_address['PRVDR_NUM']+' - '+'4953 Section Avenue, Norwood, OH 45212',
                              df4['FullAddress'])

df4['FullAddress'] = np.where(df4['PRVDR_NUM'] == 'MISS02', 
                              df_address['PRVDR_NUM']+' - '+'4647 Monroe Street, Toledo, OH 43623',
                              df4['FullAddress'])

df4['FullAddress'] = np.where(df4['PRVDR_NUM'] == 'MISS03', 
                              df_address['PRVDR_NUM']+' - '+'6046 APPALOOSA TRAIL, San Angelo, TX 76901',
                              df4['FullAddress'])

# %% [markdown]
# ## Checking and cleaning centers without address

# %%
print(len(df_address))
df_address_clean = df_address[['FullAddress', 'PRVDR_NUM']]
print(len(df_address_clean))
df_address_clean.sample(10)
# Out:
# 241
# 241
#                                                            FullAddress  \
# 1009  367518 - 979 TIBBETTS-WICK ROAD, SUITE A, GIRARD, OH, 44420, USA
# 216   213301 - 707 NORTH  BROADWAY, BALTIMORE, MD, 21205, USA
# 708   340040 - 2100 STANTONSBURG RD, GREENVILLE, NC, 27834, USA
# 1334  513030 - 1160 VAN VOORHIS ROAD, MORGANTOWN, WV, 26504, USA
# 722   173026 - 5701 W 110TH STREET, OVERLAND PARK, KS, 66211, USA
# 288   310085 - 300 MARKET STREET, SADDLE BROOK, NJ, 07662, USA
# 235   053307 - 3777 SOUTH BASCOM AVENUE, CAMPBELL, CA, 95008, USA
# 727   152020 - 8050 TOWNSHIP LINE RD, INDIANAPOLIS, IN, 46260, USA
# 238   056107 - 1676 MEDICAL CTR DR., SAN BERNARDINO, CA, 92411, USA
# 463   233026 - 235 WEALTHY SE, GRAND RAPIDS, MI, 49503, USA
#
#      PRVDR_NUM
# 1009  367518
# 216   213301
# 708   340040
# 1334  513030
# 722   173026
# 288   310085
# 235   053307
# 727   152020
# 238   056107
# 463   233026

# %%
df_address_clean[(df_address_clean['FullAddress'].isna())]
# Out:
# Empty DataFrame
# Columns: [FullAddress, PRVDR_NUM]
# Index: []

# %%
list_prvdr_na = list(df_address_clean[(df_address_clean['FullAddress'].isna())]['PRVDR_NUM'])

df_address[df_address['PRVDR_NUM'].isin(list_prvdr_na)]
# Out:
# Empty DataFrame
# ...

# %% [markdown]
# ### Apparently, all centers have full address, but just in case

# %%
## using this here. If we are matching it to one of the options above, we need to comment this cell
## Notice df_address_clean only has the full address and provider number. We'll need to filter df_address, our main dataframe
df_address_clean = df_address_clean[~df_address_clean['FullAddress'].isna()]
print("Number of centers: %s " % len(df_address_clean))

## df_address is our main dataframe, so filtering it by the provider numbers with full address
list_providers_with_address = list(df_address_clean['PRVDR_NUM'].unique())
df_address = df_address[df_address['PRVDR_NUM'].isin(list_providers_with_address)]
print("Number of centers: %s " % len(df_address))
# Out:
# Number of centers: 241
# Number of centers: 241

# %%
list_providers_with_address = list(df_address_clean['PRVDR_NUM'].unique())
df_address = df_address[df_address['PRVDR_NUM'].isin(list_providers_with_address)]
print("Number of centers: %s " % len(df_address))
# Out:
# Number of centers: 241

# %% [markdown]
# ## Geocoding
#
# Usual routine, nothing new here. The merged file (`output_filename`) will have a date of the day the notebook is run and saved at the folder `csv_data`

# %%
logger = logging.getLogger("root")
logger.setLevel(logging.DEBUG)
# create console handler
ch = logging.StreamHandler()
ch.setLevel(logging.DEBUG)
logger.addHandler(ch)

#------------------ CONFIGURATION -------------------------------

# Set your Google API key here. 
# Even if using the free 2500 queries a day, its worth getting an API key since the rate limit is 50 / second.
# With API_KEY = None, you will run into a 2 second delay every 10 requests or so.
# With a "Google Maps Geocoding API" key from https://console.developers.google.com/apis/, 
# the daily limit will be 2500, but at a much faster rate.
# Example: API_KEY = 'AIzaSyC9azed9tLdjpZNjg2_kVePWvMIBq154eA'
API_KEY = 'AIzaSyCzVfCDxjCSC6K4hd4020s6PYP3OREpm5o'
# Backoff time sets how many minutes to wait between google pings when your API limit is hit
BACKOFF_TIME = 30
# Set your output file name here.
output_filename = 'csv_data/pac_facilities_and_cms_merge_'+today+'_geo_to_be_merged.csv'
# # Set your input file here
# input_filename = 'csv_data/pac_facilities_and_cms_merge.csv'
# Specify the column name in your input data that contains addresses here
address_column_name = 'FullAddress'
# Return Full Google Results? If True, full JSON results from Google are included in output
RETURN_FULL_RESULTS = False

# %%
#------------------ DATA LOADING --------------------------------

# Read the data to a Pandas Dataframe
data = df_address_clean#pd.read_csv(input_filename, dtype=object, encoding='utf8')
#data['Address'] = data['MLOCADDR']+str(', ')+data['MLOCZIP']+str(', ')+'USA'
print(len(data))
#data = data.dropna(axis=0, subset=['FullAddress'])
#print(len(data))
#data['FullAddress']# = df_address_clean['Address']+str(', ')+df_address_clean['City']+str(', ')+df_address_clean['Zipcode']+' USA'
#data = data[:23]


if address_column_name not in data.columns:
    raise ValueError("Missing Address column in input data")

# Form a list of addresses for geocoding:
# Make a big list of all of the addresses to be processed.
addresses = data[~data[address_column_name].isna()][address_column_name].tolist()


# **** DEMO DATA / IRELAND SPECIFIC! ****
# We know that these addresses are in Ireland, and there's a column for county, so add this for accuracy. 
# (remove this line / alter for your own dataset)
#addresses = (data[address_column_name] + ',' + data['County'] + ',Ireland').tolist()
addresses = (data[~data[address_column_name].isna()][address_column_name]).tolist()
# Out:
# 241

# %%
addresses
# Out:
# ['073025 - 490 BLUE HILLS AVENUE, HARTFORD, CT, 06112, USA',
#  '393030 - 475 MORGAN HIGHWAY, SCRANTON, PA, 18508, USA',
#  '393036 - 150 MUNDY STREET, WILKES BARRE TOWNSHI, PA, 18702, USA',
#  '393304 - 5324 PENN AVENUE, PITTSBURGH, PA, 15224, USA',
#  '399812 - 34TH STREET AND CIVIC CENTER BLVD, PHILADELPHIA, PA, 19104, USA',
#  '393046 - 143 EAST SECOND STREET, ERIE, PA, 16507, USA',
#  '393027 - 320 GUYS RUN ROAD, PITTSBURGH, PA, 15238, USA',
#  '393026 - 1623 MORGANTOWN ROAD, READING, PA, 19607, USA',
#  '393037 - 1850 NORMANDIE DRIVE, YORK, PA, 17404, USA',
#  '393035 - 850 SOUTH FIFTH STREET, ALLENTOWN, PA, 18103, USA',
#  '393038 - SIX FRANKLIN PLAZA, PHILADELPHIA, PA, 19102, USA',
#  '393053 - 1135 OLD WEST CHOCOLATE AVE, HUMMELSTOWN, PA, 17036, USA',
#  "393302 - ONE CHILDREN'S HOSPITAL DRIVE, PITTSBURGH, PA, 15224, USA",
#  '390110 - 1086 FRANKLIN STREET, JOHNSTOWN, PA, 15905, USA',
#  '393033 - NORTH 12TH STREET & TABOR ROAD, PHILADELPHIA, PA, 19141, USA',
# ...

# %%
#------------------	FUNCTION DEFINITIONS ------------------------

def get_google_results(address, api_key=None, return_full_response=False, n_id=6):
    """
    Get geocode results from Google Maps Geocoding API.
    
    Note, that in the case of multiple google geocode reuslts, this function returns details of the FIRST result.
    
    @param address: String address as accurate as possible. For Example "18 Grafton Street, Dublin, Ireland"
    @param api_key: String API key if present from google. 
                    If supplied, requests will use your allowance from the Google API. If not, you
                    will be limited to the free usage of 2500 requests per day.
    @param return_full_response: Boolean to indicate if you'd like to return the full response from google. This
                    is useful if you'd like additional location details for storage or parsing later.
    """
    # removing provider name
    print(address)
    # Set up your Geocoding url
    geocode_url = "https://maps.googleapis.com/maps/api/geocode/json?address={}".format(address)
    if api_key is not None:
        geocode_url = geocode_url + "&key={}".format(api_key)
        
    # Ping google for the reuslts:
    results = requests.get(geocode_url)
    # Results will be in JSON format - convert to dict using requests functionality
    results = results.json()
    
    # if there's no results or an error, return empty results.
    if len(results['results']) == 0:
        output = {
            "formatted_address" : None,
            "latitude": None,
            "longitude": None,
            "accuracy": None,
            "google_place_id": None,
            "type": None,
            "postcode": None
        }
    else:    
        answer = results['results'][0]
        output = {
            "formatted_address" : answer.get('formatted_address'),
            "latitude": answer.get('geometry').get('location').get('lat'),
            "longitude": answer.get('geometry').get('location').get('lng'),
            "accuracy": answer.get('geometry').get('location_type'),
            "google_place_id": answer.get("place_id"),
            "type": ",".join(answer.get('types')),
            "postcode": ",".join([x['long_name'] for x in answer.get('address_components') 
                                  if 'postal_code' in x.get('types')])
        }
        
    # Append some other details:    
    output['input_string'] = address
    output['id'] = n_id
    output['number_of_results'] = len(results['results'])
    output['status'] = results.get('status')
    if return_full_response is True:
        output['response'] = results
    
    return output

# %%
#------------------ PROCESSING LOOP -----------------------------
# Ensure, before we start, that the API key is ok/valid, and internet access is ok
test_result = get_google_results("London, England", API_KEY, RETURN_FULL_RESULTS)
if (test_result['status'] != 'OK') or (test_result['formatted_address'] != 'London, UK'):
    logger.warning("There was an error when testing the Google Geocoder.")
    raise ConnectionError('Problem with test results from Google Geocode - check your API key and internet connection.')

# Create a list to hold results
results = []
# Go through each address in turn
for address in addresses:
    # spearating id for merging later UF
    len_id = 6
    number_id = address[:len_id]
    address = address[len_id+3:]
    print(number_id, address)
    
    # While the address geocoding is not finished:
    geocoded = False
    while geocoded is not True:
        # Geocode the address with google
        try:
            geocode_result = get_google_results(address, API_KEY, return_full_response=RETURN_FULL_RESULTS, n_id=number_id)
        except Exception as e:
            logger.exception(e)
            logger.error("Major error with {}".format(address))
            logger.error("Skipping!")
            geocoded = True
            
        # If we're over the API limit, backoff for a while and try again later.
        if geocode_result['status'] == 'OVER_QUERY_LIMIT':
            logger.info("Hit Query Limit! Backing off for a bit.")
            time.sleep(BACKOFF_TIME * 60) # sleep for 30 minutes
            geocoded = False
        else:
            # If we're ok with API use, save the results
            # Note that the results might be empty / non-ok - log this
            if geocode_result['status'] != 'OK':
                logger.warning("Error geocoding {}: {}".format(address, geocode_result['status']))
            logger.debug("Geocoded: {}: {}".format(address, geocode_result['status']))
            results.append(geocode_result)           
            geocoded = True

    # Print status every 100 addresses
    if len(results) % 100 == 0:
        logger.info("Completed {} of {} address".format(len(results), len(addresses)))
            
    # Every 500 addresses, save progress to file(in case of a failure so you have something!)
    if len(results) % 500 == 0:
        pd.DataFrame(results).to_csv("{}_bak".format(output_filename))

# All done
logger.info("Finished geocoding all addresses")
# Write the full results to csv using the pandas library.
pd.DataFrame(results).to_csv(output_filename, encoding='utf8')
# Out:
# London, England
# Starting new HTTPS connection (1): maps.googleapis.com:443
# https://maps.googleapis.com:443 "GET /maps/api/geocode/json?address=London,%20England&key=AIzaSyCzVfCDxjCSC6K4hd4020s6PYP3OREpm5o HTTP/1.1" 200 1883
# Starting new HTTPS connection (1): maps.googleapis.com:443
# 073025 490 BLUE HILLS AVENUE, HARTFORD, CT, 06112, USA
# 490 BLUE HILLS AVENUE, HARTFORD, CT, 06112, USA
# https://maps.googleapis.com:443 "GET /maps/api/geocode/json?address=490%20BLUE%20HILLS%20AVENUE,%20HARTFORD,%20CT,%2006112,%20USA&key=AIzaSyCzVfCDxjCSC6K4hd4020s6PYP3OREpm5o HTTP/1.1" 200 2391
# Geocoded: 490 BLUE HILLS AVENUE, HARTFORD, CT, 06112, USA: OK
# Starting new HTTPS connection (1): maps.googleapis.com:443
# 393030 475 MORGAN HIGHWAY, SCRANTON, PA, 18508, USA
# 475 MORGAN HIGHWAY, SCRANTON, PA, 18508, USA
# ...

# %% [markdown]
# __IMPORTANT__: The exact results of the geocoding varies slightly everytime it is run, but usually a few centers are not geolocated, so check if it is done right and add by hand or rereun if needed.

# %%
df_results = pd.DataFrame(results)
df_results.sample(4)
# Out:
#                                          formatted_address   latitude  \
# 57   1008 N Main St, Sikeston, MO 63801, USA                36.889624
# 212  23331 Grand Reserve Dr, Katy, TX 77494, USA            29.767584
# 202  1 Children's Way SLOT 301, Little Rock, AR 72202, USA  34.743082
# 12   Children's Hospital Dr, Pittsburgh, PA 15224, USA      40.466477
#
#      longitude          accuracy  \
# 57  -89.583285  ROOFTOP
# 212 -95.777638  ROOFTOP
# 202 -92.292250  ROOFTOP
# 12  -79.952293  GEOMETRIC_CENTER
#
#                                                                                                                           google_place_id  \
# 57   ChIJbQm4CF5GeIgRJ29-OwEo_Fw
# 212  ChIJReqVA9omQYYR5pAUqDPR_nQ
# 202  EjUxIENoaWxkcmVuJ3MgV2F5IFNMT1QgMzAxLCBMaXR0bGUgUm9jaywgQVIgNzIyMDIsIFVTQSIkGiIKFgoUChIJnTYZn1q70ocRuZF0pEF3IIkSCFNMT1QgMzAx
# ...

# %%
print(len(df_results))
df_results.status.value_counts()
# Out:
# 241
# OK    241
# Name: status, dtype: int64

# %%
df_results[df_results['status'] != 'OK']
# Out:
# Empty DataFrame
# Columns: [formatted_address, latitude, longitude, accuracy, google_place_id, type, postcode, input_string, id, number_of_results, status]
# Index: []

# %% [markdown]
# ## Merging geocoding results back to main dataframe

# %%
df_address = df_address.merge(df_results, left_on='PRVDR_NUM', right_on='id', how='left')
print(len(df_address))
# Out:
# 241

# %% [markdown]
# ## Centers & adresses not geocoded -- FIXED
#
# All resulting OK

# %%
list_addresses_not_geocoded = list(df_results[df_results['status'] != 'OK']['input_string'])

print("Centers not geocoded:")
for address in list_addresses_not_geocoded:
    display(df_address[df_address['FullAddress'].str.contains(address)][['FAC_NAME_NS','FAC_NAME_CMS','FullAddress', 'latitude', 'longitude']])
# Out:
# Centers not geocoded:

# %% [markdown]
# ### Any other centers without latitude or longitude?

# %%
display(df_address[df_address['latitude'].isna()][['FAC_NAME_NS','FAC_NAME_CMS','FullAddress', 'latitude', 'longitude']])
# Out:
# Empty DataFrame
# Columns: [FAC_NAME_NS, FAC_NAME_CMS, FullAddress, latitude, longitude]
# Index: []

# %%
display(df_address[df_address['longitude'].isna()][['FAC_NAME_NS','FAC_NAME_CMS','FullAddress', 'latitude', 'longitude']])
# Out:
# Empty DataFrame
# Columns: [FAC_NAME_NS, FAC_NAME_CMS, FullAddress, latitude, longitude]
# Index: []

# %% [markdown]
# ## Write geocoded dataset to file
#
# Not needed anymore, so commented out

# %%
#df_address.to_csv('csv_data/pac_facilities_and_cms_merge_geocoded_'+today+'.csv', index=False)

# %% [markdown]
# # <font color="red">FINAL dataset</font>: to be published
#
# <s>Which fields do we want to make available?</s>
#
# Using list NS provided

# %%
df_address['STATUS_desc'].value_counts()
# Out:
# PAC facility accepting adolescent patients    73
# PAC facility with embedded pediatric unit     68
# PAC facility accepting pediatric patients     66
# Free-standing pediatric PAC facility          34
# Name: STATUS_desc, dtype: int64

# %%
#list(df_address.columns)

# %%
## Copying here the columns created by Nadine and a few others used to map the centers

# columns_to_publish = ['STATE',
#                      'FAC_NAME_NS',
#                      'FAC_NAME_CMS',
#                      'ST_ADR_NS',
#                      'ST_ADR_CMS',
#                      'CITY_NAME',
#                       'PHONE',
#                      'INFO_PHONE',
#                      'INFO_WEBSITE',
#                      'WEB_URL',
#                      'INPT_BEDS',
#                      'INPT_BEDS_NOTE',
#                      'ADMIT_AGE_MIN',
#                      'ADMIT_AGE_MIN_NOTE',
#                      'ADMIT_AGE_MAX',
#                      'ADMIT_AGE_MAX_NOTE',
#                      'TRACH',
#                      'TRACH_NOTE',
#                      'VENT',
#                      'VENT_NOTE',
#                      'PN',
#                      'PN_NOTE',
#                      'COMMENT',
#                      'STATUS',
#                      'PRVDR_NUM',
#                      'ZIP',
#                      'SOURCE',
#                      'FREE',
#                      'CONTACT_EMAIL',
#                      'PRVDR_NUM_CHECK',
#                      'STATUS_desc',
#                      'FullAddress',
#                      'formatted_address',
#                      'latitude',
#                      'longitude',
#                      'INPT_BEDS']

## Columns from NS 03/29/2023
columns_to_publish = ['STATE',
                    'FAC_NAME',
                    'ST_ADR',
                    'PHONE',
                    'INPT_BEDS',
                    'ADMIT_AGE_MIN',
                    'ADMIT_AGE_MAX',
                    'TRACH',
                    'VENT',
                    'PN',
                    'STATUS',
                    'PRVDR_NUM',
                    'ZIP',
                    'FREE', 
                    'latitude',
                    'longitude',]

# %%
## renaming centers name and address
df_address = df_address.rename( columns={'FAC_NAME_NS':'FAC_NAME',
                                         'FullAddress': 'ST_ADR'})

df_address[columns_to_publish].shape
# Out:
# (241, 16)

# %%
df_address[columns_to_publish].to_csv('csv_data/pac_facilities_dataset_'+today+'.csv', index=False)
